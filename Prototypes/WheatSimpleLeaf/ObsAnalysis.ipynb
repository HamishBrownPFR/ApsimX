# %%
import datetime as dt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import APSIMGraphHelpers as AGH
import GraphHelpers as GH
import matplotlib.dates as mdates
import MathsUtilities as MUte
import sqlite3

# %%
MasterfilePath = r'C:\GitHubRepos\ApsimX\Tests\Validation\Wheat\Wheat.db'

# %%
con = sqlite3.connect(MasterfilePath)
Simulations = pd.read_sql("Select * from _Simulations",con)
con.close()
Simulations.set_index('ID',inplace=True)
Simulations.sort_index(inplace=True)
Simulations.sort_index(inplace=True, axis=1)

# %%
SensibilityFolders = ['CO2AndTranspirationEfficiency',
'CO2AndTemperatureInteractions',
'ProteinAccumulation',
'LeafAppearance',
'TerminalWaterStress',
'DetailedDynamics']

# %%
con = sqlite3.connect(MasterfilePath)
HarvestPred = pd.read_sql("Select * from HarvestReport",con).dropna(axis=1,how='all')
con.close()
HarvestPred.loc[:,'SimulationName'] = [Simulations.loc[x,'Name'] for x in HarvestPred.SimulationID]
HarvestPred.set_index(['SimulationName','Clock.Today'],drop=False,inplace=True)
HarvestPred.sort_index(inplace=True)
HarvestPred.sort_index(inplace=True,axis=1)

# Filter outputs from sensibility tests
validationFilter = [x not in SensibilityFolders for x in HarvestPred.FolderName]
HarvestPred = HarvestPred.loc[validationFilter,:].copy()
HarvestPred.dropna(how='all',axis=1,inplace=True)
HarvestPred.loc[:,'Wheat.SowingData.Cultivar'] = [x.title() for x in HarvestPred.loc[:,'Wheat.SowingData.Cultivar']]
validationFilter = [x not in SensibilityFolders for x in HarvestPred.FolderName]
HarvestPred = HarvestPred.loc[validationFilter,:].copy()
HarvestPred.dropna(how='all',axis=1,inplace=True)

# Replace Experiment with values that have had folder name pathed in where no experiment is present
HarvestPred.loc[[x is None for x in HarvestPred.Experiment],'Experiment'] = HarvestPred.loc[[x is None for x in HarvestPred.Experiment],'FolderName']

# %%
SowIndices = ['IWeather.Latitude',
    'IWeather.Longitude',
    'LocationInfo.Script.Country',
    'LocationInfo.Script.Region',
    'LocationInfo.Script.State',
    'Wheat.SowingData.Cultivar',
    'Experiment',
    'FolderName']

def getValue(ind,var,HarvestPred):
    try:
        return HarvestPred.loc[ind,var].values[0]
    except:
        return ""

con = sqlite3.connect(MasterfilePath)
Observed = pd.read_sql("Select * from Observed",con).dropna(axis=1,how='all')
con.close()
Observed.loc[:,'SimulationName'] = [Simulations.loc[x,'Name'] for x in Observed.SimulationID]
Observed.set_index(['SimulationName','Clock.Today'],drop=False,inplace=True)
Observed.sort_index(inplace=True)
Observed.sort_index(inplace=True,axis=1)
for s in SowIndices:
    Observed.loc[:,s] = [getValue(x,s,HarvestPred) for x in Observed.index.get_level_values(0)]

# %%
con = sqlite3.connect(MasterfilePath)
DailyPred = pd.read_sql("Select * from DailyReport",con)
con.close()
DailyPred.loc[:,'SimulationName'] = [Simulations.loc[x,'Name'] for x in DailyPred.SimulationID]
DailyPred.set_index(['SimulationName','Clock.Today'],drop=False,inplace=True)
DailyPred.sort_index(inplace=True)
DailyPred.sort_index(inplace=True,axis=1)
validationFilter = [x not in SensibilityFolders for x in DailyPred.FolderName]
DailyPred = DailyPred.loc[validationFilter,:].copy()
DailyPred.dropna(how='all',axis=1,inplace=True)
# Replace Experiment with values that have had folder name pathed in where no experiment is present
DailyPred.loc[:,'Experiment'] = [HarvestPred.loc[x,'Experiment'] for x in DailyPred.index.get_level_values(0)]

## Join NDVI data into daily obs
con = sqlite3.connect(MasterfilePath)
NDVIPred = pd.read_sql("Select * from NDVIDailyReport",con)
con.close()
NDVIPred.loc[:,'SimulationName'] = [Simulations.loc[x,'Name'] for x in NDVIPred.SimulationID]
NDVIPred.set_index(['SimulationName','Clock.Today'],drop=False,inplace=True)
NDVIPred.sort_index(inplace=True)
NDVIPred.sort_index(inplace=True,axis=1)

validationFilter = [x not in SensibilityFolders for x in NDVIPred.FolderName]
NDVIPred = NDVIPred.loc[validationFilter,:].copy()
NDVIPred.dropna(how='all',axis=1,inplace=True)
##Join NDVI predictions in with others 
for i in NDVIPred.index:
    DailyPred.loc[i,'NDVIModel.Script.NDVI'] = NDVIPred.loc[i,'NDVIModel.Script.NDVI']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 15
#      12 DailyPred.loc[:,'Experiment'] = [HarvestPred.loc[x,'Experiment'] for x in DailyPred.index.get_level_values(0)]
#      14 ## Join NDVI data into daily obs
# ---> 15 con = sqlite3.connect(filePath)
#      16 NDVIPred = pd.read_sql("Select * from NDVIDailyReport",con)
#      17 con.close()
#
# NameError: name 'filePath' is not defined

# %%
## Join NDVI data into daily obs
con = sqlite3.connect(MasterfilePath)
NDVIPred = pd.read_sql("Select * from NDVIDailyReport",con)
con.close()
NDVIPred.loc[:,'SimulationName'] = [Simulations.loc[x,'Name'] for x in NDVIPred.SimulationID]
NDVIPred.set_index(['SimulationName','Clock.Today'],drop=False,inplace=True)
NDVIPred.sort_index(inplace=True)
NDVIPred.sort_index(inplace=True,axis=1)

validationFilter = [x not in SensibilityFolders for x in NDVIPred.FolderName]
NDVIPred = NDVIPred.loc[validationFilter,:].copy()
NDVIPred.dropna(how='all',axis=1,inplace=True)
##Join NDVI predictions in with others 
for i in NDVIPred.index:
    DailyPred.loc[i,'NDVIModel.Script.NDVI'] = NDVIPred.loc[i,'NDVIModel.Script.NDVI']

# %%
MasterIndexVars = ['Clock.Today',
'IWeather.MaxT',
'IWeather.MinT',
'IWeather.Radn',
'SimulationID',
'SimulationName',
'Wheat.DaysAfterSowing',
'Wheat.Phenology.AccumulatedTT',
#'Wheat.Phenology.CurrentPhase.Name',
'Wheat.Phenology.CurrentStageName',
'Wheat.Phenology.Stage']

for iv in MasterIndexVars:
    Observed.loc[:,iv] = DailyPred.reindex(Observed.index).loc[:,iv]

# %%
list(Observed.columns)
# Out:
# ['(Wheat.Leaf.Transpiration + ISoilWater.Es + MicroClimate.PrecipitationInterception)',
#  'CheckpointID',
#  'Clock.Today',
#  'NDVIModel.Script.NDVI',
#  'NDVIModel.Script.NDVI.se',
#  'NDVIModel.Script.NDVIError',
#  'Notes',
#  'ObservedLayers.SW(1)',
#  'ObservedLayers.SW(1)Error',
#  'ObservedLayers.SW(10)',
#  'ObservedLayers.SW(10)Error',
#  'ObservedLayers.SW(2)',
#  'ObservedLayers.SW(2)Error',
#  'ObservedLayers.SW(3)',
#  'ObservedLayers.SW(3)Error',
#  'ObservedLayers.SW(4)',
#  'ObservedLayers.SW(4)Error',
#  'ObservedLayers.SW(5)',
#  'ObservedLayers.SW(5)Error',
#  'ObservedLayers.SW(6)',
#  'ObservedLayers.SW(6)Error',
#  'ObservedLayers.SW(7)',
#  'ObservedLayers.SW(7)Error',
#  'ObservedLayers.SW(8)',
#  'ObservedLayers.SW(8)Error',
#  'ObservedLayers.SW(9)',
#  'ObservedLayers.SW(9)Error',
#  'SimulationID',
#  'SimulationName',
#  'Soil.Water.Volumetric(1)',
#  'Soil.Water.Volumetric(10)',
#  'Soil.Water.Volumetric(2)',
#  'Soil.Water.Volumetric(3)',
#  'Soil.Water.Volumetric(4)',
#  'Soil.Water.Volumetric(5)',
#  'Soil.Water.Volumetric(6)',
#  'Soil.Water.Volumetric(7)',
#  'Soil.Water.Volumetric(8)',
#  'Soil.Water.Volumetric(9)',
#  'Wheat.AboveGround.N',
#  'Wheat.AboveGround.NConc',
#  'Wheat.AboveGround.NError',
#  'Wheat.AboveGround.Nconc.se',
#  'Wheat.AboveGround.Wt',
#  'Wheat.AboveGround.Wt.se',
#  'Wheat.AboveGround.WtError',
#  'Wheat.DaysAfterSowing',
#  'Wheat.Ear.N',
#  'Wheat.Ear.NConc',
#  'Wheat.Ear.Number',
#  'Wheat.Ear.Wt',
#  'Wheat.Ear.WtProportion',
#  'Wheat.Grain.Density',
#  'Wheat.Grain.Density.se',
#  'Wheat.Grain.FWt',
#  'Wheat.Grain.FWt15',
#  'Wheat.Grain.LiveFWt',
#  'Wheat.Grain.Moisture.se',
#  'Wheat.Grain.N',
#  'Wheat.Grain.NConc',
#  'Wheat.Grain.NError',
#  'Wheat.Grain.Number',
#  'Wheat.Grain.NumberError',
#  'Wheat.Grain.Protein',
#  'Wheat.Grain.Protein.se',
#  'Wheat.Grain.ProteinError',
#  'Wheat.Grain.Screenings',
#  'Wheat.Grain.Screenings.se',
#  'Wheat.Grain.Size',
#  'Wheat.Grain.Size.se',
#  'Wheat.Grain.SizeError',
#  'Wheat.Grain.WaterContent',
#  'Wheat.Grain.Wt',
#  'Wheat.Grain.Wt.se',
#  'Wheat.Grain.WtError',
#  'Wheat.Leaf.CoverGreen',
#  'Wheat.Leaf.CoverTotal',
#  'Wheat.Leaf.CoverTotalError',
#  'Wheat.Leaf.Dead.N',
#  'Wheat.Leaf.Dead.NConc',
#  'Wheat.Leaf.Dead.NError',
#  'Wheat.Leaf.Dead.NError.1',
#  'Wheat.Leaf.Dead.Wt',
#  'Wheat.Leaf.Dead.WtError',
#  'Wheat.Leaf.DeadCohortNo',
#  'Wheat.Leaf.DeadWtProportion',
#  'Wheat.Leaf.ExtinctionCoefficient',
#  'Wheat.Leaf.Height',
#  'Wheat.Leaf.Height.se',
#  'Wheat.Leaf.HeightError',
#  'Wheat.Leaf.Height_1',
#  'Wheat.Leaf.LAI',
#  'Wheat.Leaf.LAIError',
#  'Wheat.Leaf.Ligules',
#  'Wheat.Leaf.Live.N',
#  'Wheat.Leaf.Live.NConc',
#  'Wheat.Leaf.Live.NConcError',
#  'Wheat.Leaf.Live.NError',
#  'Wheat.Leaf.Live.StorageWt',
#  'Wheat.Leaf.Live.Wt',
#  'Wheat.Leaf.Live.WtError',
#  'Wheat.Leaf.LiveWtProportion',
#  'Wheat.Leaf.N',
#  'Wheat.Leaf.NError',
#  'Wheat.Leaf.SpecificAreaCanopy',
#  'Wheat.Leaf.SpecificAreaCanopyError',
#  'Wheat.Leaf.StemNumberPerPlant',
#  'Wheat.Leaf.StemPopulation',
#  'Wheat.Leaf.StemPopulation.se',
#  'Wheat.Leaf.Tips',
#  'Wheat.Leaf.TotalSpecificArea',
#  'Wheat.Leaf.Wt',
#  'Wheat.Leaf.WtError',
#  'Wheat.Phenology.AnthesisDASError',
#  'Wheat.Phenology.CAMP.TSHS',
#  'Wheat.Phenology.CAMP.VSHS',
#  'Wheat.Phenology.CurrentStageName',
#  'Wheat.Phenology.EmergenceDAS',
#  'Wheat.Phenology.FinalLeafNumber',
#  'Wheat.Phenology.FinalLeafNumberError',
#  'Wheat.Phenology.FlagLeafDAS',
#  'Wheat.Phenology.FloweringDAS',
#  'Wheat.Phenology.HaunStage',
#  'Wheat.Phenology.HaunStageError',
#  'Wheat.Phenology.HeadingDAS',
#  'Wheat.Phenology.MaturityDAS',
#  'Wheat.Phenology.MaturityDASError',
#  'Wheat.Phenology.Stage',
#  'Wheat.Phenology.TerminalSpikeletDAS',
#  'Wheat.Phenology.Zadok.Stage',
#  'Wheat.Phenology.Zadok.StageError',
#  'Wheat.Population',
#  'Wheat.Population.se',
#  'Wheat.PopulationError',
#  'Wheat.SowingData.Cultivar',
#  'Wheat.SpecificAreaExpanding',
#  'Wheat.Spike.HeadNumber',
#  'Wheat.Spike.HeadNumber.se',
#  'Wheat.Spike.HeadNumberError',
#  'Wheat.Spike.Live.StorageWt',
#  'Wheat.Spike.N',
#  'Wheat.Spike.NConc',
#  'Wheat.Spike.NError',
#  'Wheat.Spike.Wt',
#  'Wheat.Spike.WtError',
#  'Wheat.Stem.AreaIndex',
#  'Wheat.Stem.AreaIndexError',
#  'Wheat.Stem.Live.StorageWt',
#  'Wheat.Stem.N',
#  'Wheat.Stem.NConc',
#  'Wheat.Stem.NError',
#  'Wheat.Stem.Wt',
#  'Wheat.Stem.WtError',
#  'Wheat.Stem.WtProportion',
#  'Wheat.Structure.TotalStemPopnError',
#  'Wleat.Leaf.Wt',
#  'sum(ObservedLayers.SWmm)',
#  'sum(ObservedLayers.SWmm)Error',
#  'sum(Soil.Water.MM)',
#  'IWeather.Latitude',
#  'IWeather.Longitude',
#  'LocationInfo.Script.Country',
#  'LocationInfo.Script.Region',
#  'LocationInfo.Script.State',
#  'Experiment',
#  'FolderName',
#  'IWeather.MaxT',
#  'IWeather.MinT',
#  'IWeather.Radn',
#  'Wheat.Phenology.AccumulatedTT']

# %%
Observed.loc[:,['Wheat.Spike.Wt','Wheat.Stem.Wt']].dropna()
# Out:
#                                                   Wheat.Spike.Wt  \
# SimulationName               Clock.Today
# Ginninderra1991N0CvJanz      1991-11-05 12:00:00      196.000000
# Ginninderra1991N120CvJanz    1991-11-05 12:00:00      239.000000
# Ginninderra1991N160CvJanz    1991-11-05 12:00:00      236.000000
# Ginninderra1991N200CvJanz    1991-11-05 12:00:00      250.000000
# Ginninderra1991N240CvJanz    1991-11-05 12:00:00      244.000000
# ...                                                          ...
# Wakanui2016Sow24-FebCmNormal 2017-02-10 12:00:00      302.655370
# Wakanui2016Sow29-MarCmNormal 2017-02-10 12:00:00      308.064917
# Wakanui2017Sow09-MarCmNormal 2018-01-23 12:00:00      257.731855
# Wakanui2017Sow19-AprCmNormal 2018-01-29 12:00:00      212.767688
# Wakanui2017Sow30-MarCmNormal 2018-01-29 12:00:00      257.132583
#
#                                                   Wheat.Stem.Wt
# SimulationName               Clock.Today
# Ginninderra1991N0CvJanz      1991-11-05 12:00:00     632.000000
# Ginninderra1991N120CvJanz    1991-11-05 12:00:00     662.000000
# Ginninderra1991N160CvJanz    1991-11-05 12:00:00     665.000000
# Ginninderra1991N200CvJanz    1991-11-05 12:00:00     681.000000
# Ginninderra1991N240CvJanz    1991-11-05 12:00:00     664.000000
# ...                                                         ...
# Wakanui2016Sow24-FebCmNormal 2017-02-10 12:00:00     961.143017
# Wakanui2016Sow29-MarCmNormal 2017-02-10 12:00:00    1142.226750
# Wakanui2017Sow09-MarCmNormal 2018-01-23 12:00:00     659.985688
# Wakanui2017Sow19-AprCmNormal 2018-01-29 12:00:00     730.061935
# Wakanui2017Sow30-MarCmNormal 2018-01-29 12:00:00     725.394989
#
# [296 rows x 2 columns]

# %%
plt.plot(Observed.loc[:,'Wheat.Stem.Wt'],Observed.loc[:,'Wheat.Spike.Wt'],'o')

# %%
vars = ['Wheat.Spike.Wt','Wheat.Stem.Wt']+['Experiment']
data = Observed.loc[:,vars].dropna()
Experiments = data.Experiment.drop_duplicates()
for e in Experiments:
    exData = data.loc[data.Experiment == e,:]
    plt.plot(exData.loc[:,vars[1]],exData.loc[:,vars[0]],'o',label=e)
plt.legend(bbox_to_anchor=(1.45, 1),numpoints=1)
plt.plot(

# %%
vars = ['Wheat.Spike.Wt','Wheat.Phenology.Stage','Wheat.Stem.Wt']+['Experiment']
data = Observed.loc[:,vars].dropna()
Experiments = data.Experiment.drop_duplicates()
for e in Experiments:
    exData = data.loc[data.Experiment == e,:]
    plt.plot(exData.loc[:,'Wheat.Phenology.Stage'],exData.loc[:,'Wheat.Spike.Wt']/exData.loc[:,'Wheat.Stem.Wt'],'o',label=e)
plt.legend(bbox_to_anchor=(1.45, 1),numpoints=1)
plt.plot([5.8,6.0,7.0,8.0,9.0,10.0,11.0],
         [0.0,.01,.33,.43,.43,.43,.43],'-')

# %%
vars = ['Wheat.Spike.Wt','Wheat.Phenology.Stage','Wheat.Stem.Wt']+['Experiment']
data = Observed.loc[:,vars].dropna()
Experiments = data.Experiment.drop_duplicates()
for e in Experiments:
    exData = data.loc[data.Experiment == e,:]
    plt.plot(exData.loc[:,'Wheat.Phenology.Stage'],exData.loc[:,'Wheat.Spike.Wt'],'o',label=e)
plt.legend(bbox_to_anchor=(1.45, 1),numpoints=1)

# %%
data
# Out:
#                                                   Wheat.Spike.Wt  \
# SimulationName               Clock.Today
# Ginninderra1991N0CvJanz      1991-11-05 12:00:00      196.000000
# Ginninderra1991N120CvJanz    1991-11-05 12:00:00      239.000000
# Ginninderra1991N160CvJanz    1991-11-05 12:00:00      236.000000
# Ginninderra1991N200CvJanz    1991-11-05 12:00:00      250.000000
# Ginninderra1991N240CvJanz    1991-11-05 12:00:00      244.000000
# ...                                                          ...
# Wakanui2016Sow24-FebCmNormal 2017-02-10 12:00:00      302.655370
# Wakanui2016Sow29-MarCmNormal 2017-02-10 12:00:00      308.064917
# Wakanui2017Sow09-MarCmNormal 2018-01-23 12:00:00      257.731855
# Wakanui2017Sow19-AprCmNormal 2018-01-29 12:00:00      212.767688
# Wakanui2017Sow30-MarCmNormal 2018-01-29 12:00:00      257.132583
#
#                                                   Wheat.Stem.Wt  \
# SimulationName               Clock.Today
# Ginninderra1991N0CvJanz      1991-11-05 12:00:00     632.000000
# Ginninderra1991N120CvJanz    1991-11-05 12:00:00     662.000000
# Ginninderra1991N160CvJanz    1991-11-05 12:00:00     665.000000
# Ginninderra1991N200CvJanz    1991-11-05 12:00:00     681.000000
# Ginninderra1991N240CvJanz    1991-11-05 12:00:00     664.000000
# ...                                                         ...
# Wakanui2016Sow24-FebCmNormal 2017-02-10 12:00:00     961.143017
# Wakanui2016Sow29-MarCmNormal 2017-02-10 12:00:00    1142.226750
# Wakanui2017Sow09-MarCmNormal 2018-01-23 12:00:00     659.985688
# Wakanui2017Sow19-AprCmNormal 2018-01-29 12:00:00     730.061935
# Wakanui2017Sow30-MarCmNormal 2018-01-29 12:00:00     725.394989
#
#                                                        Experiment
# SimulationName               Clock.Today
# Ginninderra1991N0CvJanz      1991-11-05 12:00:00  Ginninderra1991
# Ginninderra1991N120CvJanz    1991-11-05 12:00:00  Ginninderra1991
# Ginninderra1991N160CvJanz    1991-11-05 12:00:00  Ginninderra1991
# Ginninderra1991N200CvJanz    1991-11-05 12:00:00  Ginninderra1991
# Ginninderra1991N240CvJanz    1991-11-05 12:00:00  Ginninderra1991
# ...                                                           ...
# Wakanui2016Sow24-FebCmNormal 2017-02-10 12:00:00      Wakanui2016
# Wakanui2016Sow29-MarCmNormal 2017-02-10 12:00:00      Wakanui2016
# Wakanui2017Sow09-MarCmNormal 2018-01-23 12:00:00      Wakanui2017
# Wakanui2017Sow19-AprCmNormal 2018-01-29 12:00:00      Wakanui2017
# Wakanui2017Sow30-MarCmNormal 2018-01-29 12:00:00      Wakanui2017
#
# [296 rows x 3 columns]
