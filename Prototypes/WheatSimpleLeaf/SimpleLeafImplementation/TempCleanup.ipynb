# %%
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET
import xmltodict, json
import ast
import numbers
import shlex # package to construct the git command to subprocess format
import subprocess 
# %matplotlib inline

# %%
SensibilityReport

# %%
## Read wheat test file into json object
with open('C:\GitHubRepos\ApsimX\Tests\Validation\Wheat\Wheat.apsimx','r') as WheatTestsJSON:
    WheatTests = json.load(WheatTestsJSON)
    WheatTestsJSON.close()
    ## read prototype wheat file into json object

# %%
def FindReports(Parent,reportName,simulationName):
    if Parent["$type"] == "Models.Core.Simulation, Models":
        simulationName = Parent["Name"]
    for model in Parent['Children']:
        if model["$type"] == "Models.Report, Models":
            if model["Name"] == reportName:
                print(simulationName)
        FindReports(model,reportName,simulationName)

# %%
FindReports(WheatTests,"DailyReport","")
# Out:
# APS26NRate160WaterWet
# APS6Base
# APS14StubbleBareNRate0
# APS2Base
# RowSpace
# Gatton94Base
# Gatton2009Base
# Gatton2011Base
# 14SOWbase
# 14VPbase
# 15TraitModbase
# 16TraitModbase
# Goondiwindi2011Base
# Nangwee2012Base
# Bungunya2012Base
# Goondiwindi1996Base
# Miles1996Base
# Emerald1996Base
# Biloela1996Base
# Moree1996Base
# Mer86Base
# Mer73Base
# Cunderdin97Base
# WonganBase
# Konya09
# Konya11
# PalmerstonNorth1989Base
# LincolnBase
# SDtrialBase
# Lincoln1994Base
# Baxters
# Rainshelter2013
# Lincoln2015
# Leeston2013Base
# Wakanui2014Base
# Wakanui2015Base
# Wakanui2016Base
# Wakanui2017Base
# Wheat
# Lincoln23Base
# LincolnCPTOtane
# LincolnCPTClaire
# Wagga91Base
# Ginninderra91Base
# Ketema2013
# Ketema2014
# YarrabahCreek
# MouseBase
# Walpeup2011Base
# Walpeup2012Base
# Minnipa2012Base
# Temora2012Base
# Birchip2011Base
# Tarlee2011Base
# Tamworth1992Base
# Griffith1983Base
# Griffith1984Base
# FAR WAA W20-01abase
# FAR WAA W20-01bbase
# FAR WAE W21-05base
# FAR WAE W22-02base
# FAR DMC W20-03base
# FAR DMC W20-05base
# FAR VIC W22-03-2base
# FAR HYC W17-01-1base
# FAR HYC W17-01-2base
# FAR HYC W17-02-1base
# FAR HYC W17-02-2base
# FAR TAS W16-01-1base
# FAR TAS W16-01-2base
# FAR TAS W16-06base
# FAR TAS W16-08base
# FAR HYC W18-02-2base
# FAR HYC W18-02-2abase
# FAR HYC W18-08-1base
# FAR HYC W19-03-1base
# FAR HYC W19-06-1base
# FAR TAS W21-03-1base
# FAR SAC W18-01base
# FAR SAC W18-02base
# FAR SAC W19-01base
# FAR SAC W19-02base
# FAR SAC W20-03-2base
# FAR SAC W20-05-1base
# FAR SAC W22-03-2base
# FAR RRC W21-03base
# FAR RRC W22-03base
# Lonzee04
# Lonzee06
# Lonzee08
# Maricopa92_93
# Maricopa93_94
# Maricopa95_96
# Maricopa96_97
# Yucheng02
# Yucheng03
# Yucheng04
# Gorgan05
# Jamma
# CEBase
# PNGrowthRooms
# LincolnUniBiotron
# WaggaWagga2019Base
# Callington2019Base
# Dale2019Base
# YanYean2019Base
# WaggaWagga2020Base
# Urrbrae2020Base
# Dale2020Base
# YanYean2020Base
# GrainFillingBase
# WaterResponseBase
# PotentialGrainSizeBase
# LeafAppearance

# %%
def StripReports(Parent):
    for model in Parent['Children']:
        #print(model["Name"])
        if model["$type"] == "Models.Report, Models":
            if model["Name"] in ["HarvestReport","DailyReport","MaxLeafSizeReport","SowingReport","NDVIDailyReport"]:
                model["VariableNames"] = None
                model["EventNames"]= None
                #print(model["Name"])
        StripReports(model)

# %%
def StripManagers(Parent):
    for model in Parent['Children']:
        #print(model["Name"])
        if model["$type"] == "Models.Manager, Models":
            if model["Name"] in ["MaxLeafSize","Harvesting"]:
                model["CodeArray"] = []
                model["Parameters"]= []
                #print(model["Name"])
        StripManagers(model)

# %%
StripReports(WheatTests)

# %%
StripManagers(WheatTests)

# %%
with open('C:\GitHubRepos\ApsimX\Tests\Validation\Wheat\Wheat.apsimx','w') as WheatTestsJSON:
    json.dump(WheatTests ,WheatTestsJSON,indent=2)
