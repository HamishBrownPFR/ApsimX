# %%
import pandas as pd

file_path = "Observed.xlsx"

# Load the Excel file
xls = pd.ExcelFile(file_path)

header_summary = {}

for sheet in xls.sheet_names:
    df = pd.read_excel(xls, sheet_name=sheet, nrows=0)  # read only header
    header_summary[sheet] = list(df.columns)

# Print results cleanly
for sheet, headers in header_summary.items():
    print(f"\nSheet: {sheet}")
    for h in headers:
        print(f"  - {h}")
# Out:
# Sheet: Observed
#   - SimulationName
#   - id
#   - Clock.Today
#   - Lentil.Phenology.CurrentStageName
#   - Chickpea_BuddingDAS
#   - Lentil.Phenology.StartBuddingDAS
#   - Fababean_BuddingDAS
#   - Lupin_BuddingDAS
#   - Chickpea_PoddingDAS
#   - Lentil.Phenology.StartPoddingDAS
#   - Fababean_PoddingDAS
#   - Lupin_PoddingDAS
#   - Chickpea_FloweringDAS
#   - Lentil.Phenology.StartFloweringDAS
#   - Fababean_FloweringDAS
#   - Lupin_FloweringDAS
#   - Chickpea_MaturityDAS
#   - Lentil.Phenology.MaturityDAS
#   - Fababean_MaturityDAS
#   - Lupin_MaturityDAS
#
# Sheet: observedDevel
#   - SimulationName
#   - id
#   - SampleDate
#   - n
#   - Chickpea_Node_no
#   - Lentil_Node_no
#   - Fababean_Node_no
#   - Lupin_Node_no
#   - Chickpea_LeafArea
#   - Lentil_LeafArea
#   - Fababean_LeafArea
#   - Lupin_LeafArea
#
# Sheet: observedHarvest
#   - SimulationName
#   - ExpNo
#   - Experiments::SiteKey
#   - Year
#   - State
#   - SiteName
#   - TrialType
#   - HarvestNo
#   - HarvestStage
#   - TOS
#   - TOSDate
#   - Variety
#   - WaterTrt
#   - Ndfa_prop
#   - Ndfa_prop_se
#   - NfixIntensity_mg_gDM
#   - NfixIntensity_mg_gDM_se
#   - NShoots_gm2
#   - NShoots_gm2_se
#   - Delta13C
#   - Delta13C_se
#   - ShNFixed_gm2
#   - ShNFixed_gm2_se
#   - AgronomyTrt
#   - Chickpea_BiomassWt
#   - Fababean_BiomassWt
#   - Lentil_BiomassWt
#   - Lupin_BiomassWt
#   - Chickpea_BiomassWt_se
#   - Fababean_BiomassWt_se
#   - Lentil_BiomassWt_se
#   - Lupin_BiomassWt_se
#   - Chickpea_GrainWt
#   - Fababean_GrainWt
#   - Lentil_GrainWt
#   - Lupin_GrainWt
#   - Chickpea_GrainWt_se
#   - Fababean_GrainWt_se
#   - Lentil_GrainWt_se
#   - Lupin_GrainWt_se
#   - Chickpea_HarvestIndex
#   - Fababean_HarvestIndex
#   - Lentil_HarvestIndex
#   - Lupin_HarvestIndex
#   - Chickpea_HarvestIndex_se
#   - Fababean_HarvestIndex_se
#   - Lentil_HarvestIndex_se
#   - Lupin_HarvestIndex_se
#   - Chickpea_Pod_count_m2
#   - Fababean_Pod_count_m2
#   - Lentil_Pod_count_m2
#   - Lupin_Pod_count_m2
#   - Chickpea_Pod_count_m2_se
#   - Fababean_Pod_count_m2_se
#   - Lentil_Pod_count_m2_se
#   - Lupin_Pod_count_m2_se
#   - Chickpea_Seed4P_count_m2
#   - Fababean_Seed4P_count_m2
#   - Lentil_Seed4P_count_m2
#   - Lupin_Seed4P_count_m2
#   - Chickpea_Seed4P_count_m2_se
#   - Fababean_Seed4P_count_m2_se
#   - Lentil_Seed4P_count_m2_se
#   - Lupin_Seed4P_count_m2_se
#   - Chickpea_SingleSeedViable4P_mg
#   - Fababean_SingleSeedViable4P_mg
#   - Lentil_SingleSeedViable4P_mg
#   - Lupin_SingleSeedViable4P_mg
#   - Chickpea_SingleSeedViable4P_mg_se
#   - Fababean_SingleSeedViable4P_mg_se
#   - Lentil_SingleSeedViable4P_mg_se
#   - Lupin_SingleSeedViable4P_mg_se
#
# Sheet: observedSoil_Total
#   - SimulationName
#   - id
#   - SampleDate
#   - PlotNo
#   - CoreNo
#   - n
#   - swTot
#   - ESw
#
# Sheet: observedSoil_Layered
#   - SimulationName
#   - id
#   - SampleDate
#   - PlotNo
#   - CoreNo
#   - CropSown
#   - sw(1)
#   - sw(2)
#   - sw(3)
#   - sw(4)
#   - sw(5)
#   - sw(6)
#   - sw(7)
#   - sw(8)
#   - sw(9)
#   - sw(10)
#   - sw(11)
#   - sw(12)
